# %%
import pandas as pd
import zipfile
import os
import matplotlib.pyplot as plt

# %%
# !pip install prophet
# Out:
# Requirement already satisfied: prophet in c:\users\tanzi\anaconda3\lib\site-packages (1.1.6)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\tanzi\anaconda3\lib\site-packages (from prophet) (1.2.5)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\tanzi\anaconda3\lib\site-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\tanzi\anaconda3\lib\site-packages (from prophet) (3.9.2)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\tanzi\anaconda3\lib\site-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays<1,>=0.25 in c:\users\tanzi\anaconda3\lib\site-packages (from prophet) (0.67)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\tanzi\anaconda3\lib\site-packages (from prophet) (4.66.5)
# Requirement already satisfied: importlib-resources in c:\users\tanzi\anaconda3\lib\site-packages (from prophet) (6.5.2)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\users\tanzi\anaconda3\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil in c:\users\tanzi\anaconda3\lib\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tanzi\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\tanzi\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tanzi\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tanzi\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\tanzi\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\tanzi\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tanzi\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tanzi\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tanzi\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2023.3)
# Requirement already satisfied: colorama in c:\users\tanzi\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\tanzi\anaconda3\lib\site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.16.0)

# %%
import pandas as pd
import zipfile

# Define dataset path (using raw string to avoid errors)
zip_path = r"C:\Users\tanzi\Personal Projects\Crime-analysis-and-prediction\crime-analysis-and-prediction\data\processed_bi.zip"
csv_filename = "processed_bi.csv"  # The actual CSV filename inside the ZIP

# Extract and read the dataset
with zipfile.ZipFile(zip_path, 'r') as z:
    with z.open(csv_filename) as f:
        df = pd.read_csv(f)

# Display the first few rows
df.head()
# Out:
#    report_id date_reported time_of_occurrence  area_code   area_name  \
# 0  200106753    2020-02-09           18:00:00          1     Central
# 1  200320258    2020-11-11           17:00:00          3   Southwest
# 2  200907217    2023-05-10           20:37:00          9    Van Nuys
# 3  200406391    2020-03-02           14:30:00          4  Hollenbeck
# 4  200606074    2020-02-12           16:15:00          6   Hollywood
#
#    part_1_2 (crime_severity)  crime_code  \
# 0                          1         330
# 1                          1         480
# 2                          1         343
# 3                          1         310
# 4                          2         805
#
#                      crime_code_description  victim_age victim_sex  \
# 0                     BURGLARY FROM VEHICLE          47       Male
# 1                             BIKE - STOLEN          19    Unknown
# 2  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)          19       Male
# 3                                  BURGLARY          27       Male
# 4                                   PIMPING          23     Female
#
#                            premises_description  case_status_description  \
# 0             BUS STOP/LAYOVER (ALSO QUERY 124)  Investigation Continued
# 1  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)  Investigation Continued
# 2                                CLOTHING STORE  Investigation Continued
# 3                                PUBLIC STORAGE  Investigation Continued
# 4                                        STREET           Adult Arrested
#
#                                    location  latitude  longitude  \
# 0   1000 S  FLOWER                       ST   34.0444  -118.2628
# 1   1400 W  37TH                         ST   34.0210  -118.3002
# 2  14000    RIVERSIDE                    DR   34.1576  -118.4387
# 3                     4500    HUNTINGTON DR   34.0881  -118.1877
# 4                                 HOLLYWOOD   34.1016  -118.3370
#
#   date_of_occurrence crime_category                       victim_descent  \
# 0         2020-02-08          Theft                              Unknown
# 1         2020-11-04          Theft                              Unknown
# 2         2020-03-10          Theft                              Unknown
# 3         2020-03-01          Theft                      Caucasian/White
# 4         2020-02-07   Sexual Crime  Latino/Hispanic or Pacific Islander
#
#        holiday
# 0      Holiday
# 1  Working day
# 2  Working day
# 3      Holiday
# 4  Working day

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 735243 entries, 0 to 735242
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   report_id                  735243 non-null  int64
#  1   date_reported              735243 non-null  object
#  2   time_of_occurrence         735243 non-null  object
#  3   area_code                  735243 non-null  int64
#  4   area_name                  735243 non-null  object
#  5   part_1_2 (crime_severity)  735243 non-null  int64
#  6   crime_code                 735243 non-null  int64
#  7   crime_code_description     735243 non-null  object
#  8   victim_age                 735243 non-null  int64
#  9   victim_sex                 735243 non-null  object
#  10  premises_description       735243 non-null  object
#  11  case_status_description    735243 non-null  object
#  12  location                   735243 non-null  object
#  13  latitude                   735243 non-null  float64
#  14  longitude                  735243 non-null  float64
#  15  date_of_occurrence         735243 non-null  object
#  16  crime_category             735243 non-null  object
#  17  victim_descent             735243 non-null  object
#  18  holiday                    735243 non-null  object
# dtypes: float64(2), int64(5), object(12)
# memory usage: 106.6+ MB

# %%
# Convert 'date_of_occurrence' column to datetime format
df["date_of_occurrence"] = pd.to_datetime(df["date_of_occurrence"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 735243 entries, 0 to 735242
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   report_id                  735243 non-null  int64
#  1   date_reported              735243 non-null  object
#  2   time_of_occurrence         735243 non-null  object
#  3   area_code                  735243 non-null  int64
#  4   area_name                  735243 non-null  object
#  5   part_1_2 (crime_severity)  735243 non-null  int64
#  6   crime_code                 735243 non-null  int64
#  7   crime_code_description     735243 non-null  object
#  8   victim_age                 735243 non-null  int64
#  9   victim_sex                 735243 non-null  object
#  10  premises_description       735243 non-null  object
#  11  case_status_description    735243 non-null  object
#  12  location                   735243 non-null  object
#  13  latitude                   735243 non-null  float64
#  14  longitude                  735243 non-null  float64
#  15  date_of_occurrence         735243 non-null  datetime64[ns]
#  16  crime_category             735243 non-null  object
#  17  victim_descent             735243 non-null  object
#  18  holiday                    735243 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(5), object(11)
# memory usage: 106.6+ MB

# %%
# Aggregate crime counts per day
crime_count_df = df.groupby("date_of_occurrence").size().reset_index(name="crime_count")

# %%
# Rename columns to match Prophet's format
crime_count_df.rename(columns={"date_of_occurrence": "ds", "crime_count": "y"}, inplace=True)

# %%
# Save preprocessed dataset for tracking
crime_count_df.to_csv("dataset_crime_count.csv", index=False)

# %%
# Display the cleaned data
crime_count_df.head()
# Out:
#           ds     y
# 0 2020-01-01  1037
# 1 2020-01-02   419
# 2 2020-01-03   464
# 3 2020-01-04   440
# 4 2020-01-05   396

# %%
print(crime_count_df.describe())  # Check for negative values
print(crime_count_df.head())  # Ensure counts make sense
# Out:
#                         ds            y
# count                 1826  1826.000000
# mean   2022-07-01 12:00:00   402.652245
# min    2020-01-01 00:00:00     5.000000
# 25%    2021-04-01 06:00:00   381.250000
# 50%    2022-07-01 12:00:00   428.000000
# 75%    2023-09-30 18:00:00   464.000000
# max    2024-12-30 00:00:00  1037.000000
# std                    NaN   130.815596
#           ds     y
# 0 2020-01-01  1037
# 1 2020-01-02   419
# 2 2020-01-03   464
# 3 2020-01-04   440
# 4 2020-01-05   396

# %%
print(crime_count_df[crime_count_df["y"] < 0])  # Should return empty
print(crime_count_df.isnull().sum())  # Should return 0 nulls
# Out:
# Empty DataFrame
# Columns: [ds, y]
# Index: []
# ds    0
# y     0
# dtype: int64

# %%
# Apply log transformation (to stabilize large values)
import numpy as np
crime_count_df["y"] = np.log1p(crime_count_df["y"])  # log(1 + y) to prevent log(0)

# %%
# Initialize and fit Prophet model
crime_count_df["floor"] = 0  # Minimum crime count is 0
from prophet import Prophet
model = Prophet()
model.fit(crime_count_df)
# Out:
# 09:31:28 - cmdstanpy - INFO - Chain [1] start processing
# 09:31:28 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Define future dates (365 days ahead)
future = model.make_future_dataframe(periods=365)

# %%
# Ensure future data also has the floor constraint
future["floor"] = 0
# Make predictions
forecast = model.predict(future)

# %%
# Reverse log transformation after prediction
forecast["yhat"] = np.expm1(forecast["yhat"])  # Convert back to original scale
forecast["yhat_lower"] = np.expm1(forecast["yhat_lower"])
forecast["yhat_upper"] = np.expm1(forecast["yhat_upper"])

# %%
print(forecast[["ds", "yhat", "yhat_lower", "yhat_upper"]].tail())
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 2186 2025-12-26  14.755238    8.539526   25.902480
# 2187 2025-12-27  14.440376    8.284824   25.118121
# 2188 2025-12-28  13.462100    7.659725   23.274317
# 2189 2025-12-29  13.327101    7.284576   23.773378
# 2190 2025-12-30  12.977450    7.186142   22.603037

# %%
fig = model.plot(forecast)
plt.title("Crime Forecasting with Prophet")
plt.xlabel("Date")
plt.ylabel("Crime Count")
plt.show()
